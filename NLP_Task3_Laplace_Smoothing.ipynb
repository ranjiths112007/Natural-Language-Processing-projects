# %%
from collections import Counter

text = 'this is a good movie this is a nice movie'
words = text.lower().split()
counts = Counter(words)
vocabulary = set(words)

test_words = ['good', 'bad', 'excellent']

# %%
total_words = len(words)
V = len(vocabulary)
print(f'Vocabulary size: {V}')
print(f'Total words: {total_words}')

for word in test_words:
    probability = (counts[word] + 1) / (total_words + V)
    print(f'{word} -> count={counts[word]}, P={probability:.6f}')
# Out:
# Vocabulary size: 7
# Total words: 10
#
# good -> count=1, P=0.117647
# bad -> count=0, P=0.058824
# excellent -> count=0, P=0.058824
